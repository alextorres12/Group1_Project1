# %%
import json
import requests
from pprint import pprint

from config import omdb_api_key
from config import tmdb_api_key

# %%
movie_name = "A Star Is Born"

url = f"https://api.themoviedb.org/3/search/movie?api_key={tmdb_api_key}&query={movie_name}&page=1"

# %%
response = requests.get(url)
movie_json = response.json()

pprint(movie_json)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/mnDvPokXpvsdPcWSjNRPhiiLOKu.jpg',
#               'genre_ids': [18, 10402, 10749],
#               'id': 332562,
#               'original_language': 'en',
#               'original_title': 'A Star Is Born',
#               'overview': 'Seasoned musician Jackson Maine discovers — and '
#                           'falls in love with — struggling artist Ally. She '
#                           'has just about given up on her dream to make it big '
#                           'as a singer — until Jack coaxes her into the '
#                           "spotlight. But even as Ally's career takes off, the "
#                           'personal side of their relationship is breaking '
#                           'down, as Jack fights an ongoing battle with his own '
#                           'internal demons.',
#               'popularity': 37.897,
# ...

# %%
print(movie_json["results"][0]["id"])
# Out:
# 332562

# %%
movie_id =  movie_json["results"][0]["id"]
url2 = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

response2 = requests.get(url2)
movie_json2 = response2.json()

pprint(movie_json2)
# Out:
# {'adult': False,
#  'backdrop_path': '/mnDvPokXpvsdPcWSjNRPhiiLOKu.jpg',
#  'belongs_to_collection': None,
#  'budget': 36000000,
#  'genres': [{'id': 18, 'name': 'Drama'},
#             {'id': 10749, 'name': 'Romance'},
#             {'id': 10402, 'name': 'Music'}],
#  'homepage': 'http://astarisbornmovie.com',
#  'id': 332562,
#  'imdb_id': 'tt1517451',
#  'original_language': 'en',
#  'original_title': 'A Star Is Born',
#  'overview': 'Seasoned musician Jackson Maine discovers — and falls in love '
#              'with — struggling artist Ally. She has just about given up on '
#              'her dream to make it big as a singer — until Jack coaxes her '
#              "into the spotlight. But even as Ally's career takes off, the "
#              'personal side of their relationship is breaking down, as Jack '
#              'fights an ongoing battle with his own internal demons.',
#  'popularity': 38.495,
#  'poster_path': '/wrFpXMNBRj2PBiN4Z5kix51XaIZ.jpg',
# ...
